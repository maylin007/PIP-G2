# %% [markdown]
# # Initialisation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("/home/maylin/Downloads/data_v6.csv")
test = pd.read_csv("/home/maylin/Downloads/data_v6.csv")
validation = pd.read_csv("/home/maylin/Downloads/data_v6.csv")

# %%
X_train = train.drop(["loc_initiator_x", "loc_initiator_y"], axis=1)
y_train = pd.DataFrame(train[["loc_initiator_x", "loc_initiator_y"]])

X_test = test.drop(["loc_initiator_x", "loc_initiator_y"], axis=1)
y_test = pd.DataFrame(test[["loc_initiator_x", "loc_initiator_y"]])

X_valid = validation.drop(["loc_initiator_x", "loc_initiator_y"], axis=1)
y_valid = pd.DataFrame(validation[["loc_initiator_x", "loc_initiator_y"]])

# %% [markdown]
# # Entrainement du modele

# %%
import math
import os

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Garbage Collector - use it like gc.collect()
import gc

# Custom Callback To Include in Callbacks List At Training Time
class GarbageCollectorCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from tqdm import tqdm
import keras.backend as K
from keras.losses import MeanSquaredError
from keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam


cst_nb_neuronne = 256 #512
cst_drop_out = 0 #0.2
nb_couche = 8

neuronal_reseau = []

for nb in tqdm(range(nb_couche)):
  neuronal_reseau += [
    layers.Dense(cst_nb_neuronne, activation='relu'),
    layers.BatchNormalization(), 
    layers.Dropout(cst_drop_out)]

def get_model():
  return keras.Sequential([
    layers.InputLayer(input_shape=(X_train.shape[1],))]
    + [layers.BatchNormalization()]
    + neuronal_reseau
    + [layers.BatchNormalization()]
    + [layers.Dense(2)])

model = get_model()

model.compile(optimizer=Adam(), loss=["mae"], metrics=[tf.keras.metrics.RootMeanSquaredError()]) 

early_stopping = callbacks.EarlyStopping(min_delta=0.001,
                                         patience=20,
                                         restore_best_weights=True)

lr_rop = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss', patience= 5,
                                              factor = np.sqrt(0.2), verbose = 1,
                                              min_lr = 5e-10)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 298.56it/s]

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size = 128,
    epochs = 250,
    callbacks=[early_stopping, lr_rop]
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))
# Out:
# Epoch 1/250
# 31/31 [==============================] - 4s 30ms/step - loss: 3.1685 - root_mean_squared_error: 4.3144 - val_loss: 3.6075 - val_root_mean_squared_error: 4.7445 - lr: 0.0010
# Epoch 2/250
# 31/31 [==============================] - 1s 20ms/step - loss: 2.4450 - root_mean_squared_error: 3.5594 - val_loss: 3.2111 - val_root_mean_squared_error: 4.1103 - lr: 0.0010
# Epoch 3/250
# 31/31 [==============================] - 1s 20ms/step - loss: 1.3725 - root_mean_squared_error: 2.2283 - val_loss: 1.0875 - val_root_mean_squared_error: 1.3218 - lr: 0.0010
# Epoch 4/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.5678 - root_mean_squared_error: 0.8689 - val_loss: 1.8570 - val_root_mean_squared_error: 2.3989 - lr: 0.0010
# Epoch 5/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.4508 - root_mean_squared_error: 0.6528 - val_loss: 1.8416 - val_root_mean_squared_error: 2.7999 - lr: 0.0010
# Epoch 6/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.3759 - root_mean_squared_error: 0.5477 - val_loss: 1.2101 - val_root_mean_squared_error: 1.6434 - lr: 0.0010
# Epoch 7/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.3098 - root_mean_squared_error: 0.4375 - val_loss: 1.0319 - val_root_mean_squared_error: 1.4012 - lr: 0.0010
# Epoch 8/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.3325 - root_mean_squared_error: 0.4637 - val_loss: 1.1748 - val_root_mean_squared_error: 1.4530 - lr: 0.0010
# Epoch 9/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.3209 - root_mean_squared_error: 0.4546 - val_loss: 0.8815 - val_root_mean_squared_error: 1.1105 - lr: 0.0010
# Epoch 10/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.2781 - root_mean_squared_error: 0.3861 - val_loss: 0.6160 - val_root_mean_squared_error: 0.7928 - lr: 0.0010
# Epoch 11/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.2842 - root_mean_squared_error: 0.3975 - val_loss: 0.5123 - val_root_mean_squared_error: 0.6599 - lr: 0.0010
# Epoch 12/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.2409 - root_mean_squared_error: 0.3404 - val_loss: 0.4185 - val_root_mean_squared_error: 0.5814 - lr: 0.0010
# Epoch 13/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.2778 - root_mean_squared_error: 0.3878 - val_loss: 0.3910 - val_root_mean_squared_error: 0.5470 - lr: 0.0010
# Epoch 14/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.2499 - root_mean_squared_error: 0.3504 - val_loss: 0.2858 - val_root_mean_squared_error: 0.3816 - lr: 0.0010
# Epoch 15/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.2357 - root_mean_squared_error: 0.3287 - val_loss: 0.3134 - val_root_mean_squared_error: 0.4948 - lr: 0.0010
# Epoch 16/250
# 31/31 [==============================] - 1s 30ms/step - loss: 0.2452 - root_mean_squared_error: 0.3407 - val_loss: 0.2774 - val_root_mean_squared_error: 0.3935 - lr: 0.0010
# Epoch 17/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.2519 - root_mean_squared_error: 0.3611 - val_loss: 0.3240 - val_root_mean_squared_error: 0.5232 - lr: 0.0010
# Epoch 18/250
# 31/31 [==============================] - 1s 29ms/step - loss: 0.2510 - root_mean_squared_error: 0.3506 - val_loss: 0.2182 - val_root_mean_squared_error: 0.3070 - lr: 0.0010
# Epoch 19/250
# 31/31 [==============================] - 1s 28ms/step - loss: 0.2226 - root_mean_squared_error: 0.3222 - val_loss: 0.2142 - val_root_mean_squared_error: 0.3232 - lr: 0.0010
# Epoch 20/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.2444 - root_mean_squared_error: 0.3458 - val_loss: 0.3548 - val_root_mean_squared_error: 0.5239 - lr: 0.0010
# Epoch 21/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.2316 - root_mean_squared_error: 0.3331 - val_loss: 0.2293 - val_root_mean_squared_error: 0.3413 - lr: 0.0010
# Epoch 22/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2143 - root_mean_squared_error: 0.3092 - val_loss: 0.2139 - val_root_mean_squared_error: 0.2795 - lr: 0.0010
# Epoch 23/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.2258 - root_mean_squared_error: 0.3238 - val_loss: 0.2741 - val_root_mean_squared_error: 0.3825 - lr: 0.0010
# Epoch 24/250
# 31/31 [==============================] - 1s 32ms/step - loss: 0.2176 - root_mean_squared_error: 0.3058 - val_loss: 0.2160 - val_root_mean_squared_error: 0.3599 - lr: 0.0010
# Epoch 25/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.2411 - root_mean_squared_error: 0.3426 - val_loss: 0.2257 - val_root_mean_squared_error: 0.3306 - lr: 0.0010
# Epoch 26/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.2095 - root_mean_squared_error: 0.3008 - val_loss: 0.2210 - val_root_mean_squared_error: 0.3484 - lr: 0.0010
# Epoch 27/250
# 30/31 [============================>.] - ETA: 0s - loss: 0.2169 - root_mean_squared_error: 0.3102
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0004472136167414639.
# 31/31 [==============================] - 1s 28ms/step - loss: 0.2159 - root_mean_squared_error: 0.3085 - val_loss: 0.2178 - val_root_mean_squared_error: 0.3143 - lr: 0.0010
# Epoch 28/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.2017 - root_mean_squared_error: 0.2825 - val_loss: 0.2217 - val_root_mean_squared_error: 0.3077 - lr: 4.4721e-04
# Epoch 29/250
# 31/31 [==============================] - 1s 30ms/step - loss: 0.1870 - root_mean_squared_error: 0.2658 - val_loss: 0.1224 - val_root_mean_squared_error: 0.1972 - lr: 4.4721e-04
# Epoch 30/250
# 31/31 [==============================] - 1s 36ms/step - loss: 0.1755 - root_mean_squared_error: 0.2520 - val_loss: 0.1356 - val_root_mean_squared_error: 0.2012 - lr: 4.4721e-04
# Epoch 31/250
# 31/31 [==============================] - 1s 28ms/step - loss: 0.1861 - root_mean_squared_error: 0.2652 - val_loss: 0.1393 - val_root_mean_squared_error: 0.2152 - lr: 4.4721e-04
# Epoch 32/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1734 - root_mean_squared_error: 0.2485 - val_loss: 0.1481 - val_root_mean_squared_error: 0.2363 - lr: 4.4721e-04
# Epoch 33/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1660 - root_mean_squared_error: 0.2354 - val_loss: 0.1273 - val_root_mean_squared_error: 0.1969 - lr: 4.4721e-04
# Epoch 34/250
# 31/31 [==============================] - ETA: 0s - loss: 0.1679 - root_mean_squared_error: 0.2457
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00020000001124561851.
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1679 - root_mean_squared_error: 0.2457 - val_loss: 0.1879 - val_root_mean_squared_error: 0.2962 - lr: 4.4721e-04
# Epoch 35/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1683 - root_mean_squared_error: 0.2361 - val_loss: 0.0868 - val_root_mean_squared_error: 0.1511 - lr: 2.0000e-04
# Epoch 36/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.1537 - root_mean_squared_error: 0.2177 - val_loss: 0.0994 - val_root_mean_squared_error: 0.1608 - lr: 2.0000e-04
# Epoch 37/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1697 - root_mean_squared_error: 0.2385 - val_loss: 0.0860 - val_root_mean_squared_error: 0.1462 - lr: 2.0000e-04
# Epoch 38/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1731 - root_mean_squared_error: 0.2438 - val_loss: 0.1049 - val_root_mean_squared_error: 0.1637 - lr: 2.0000e-04
# Epoch 39/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1501 - root_mean_squared_error: 0.2161 - val_loss: 0.0902 - val_root_mean_squared_error: 0.1480 - lr: 2.0000e-04
# Epoch 40/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1775 - root_mean_squared_error: 0.2476 - val_loss: 0.0976 - val_root_mean_squared_error: 0.1668 - lr: 2.0000e-04
# Epoch 41/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1794 - root_mean_squared_error: 0.2551 - val_loss: 0.0941 - val_root_mean_squared_error: 0.1571 - lr: 2.0000e-04
# Epoch 42/250
# 31/31 [==============================] - ETA: 0s - loss: 0.1600 - root_mean_squared_error: 0.2264
# Epoch 42: ReduceLROnPlateau reducing learning rate to 8.944272334829278e-05.
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1600 - root_mean_squared_error: 0.2264 - val_loss: 0.0875 - val_root_mean_squared_error: 0.1501 - lr: 2.0000e-04
# Epoch 43/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1572 - root_mean_squared_error: 0.2257 - val_loss: 0.0777 - val_root_mean_squared_error: 0.1428 - lr: 8.9443e-05
# Epoch 44/250
# 31/31 [==============================] - 1s 30ms/step - loss: 0.1636 - root_mean_squared_error: 0.2321 - val_loss: 0.0866 - val_root_mean_squared_error: 0.1449 - lr: 8.9443e-05
# Epoch 45/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1493 - root_mean_squared_error: 0.2137 - val_loss: 0.0821 - val_root_mean_squared_error: 0.1434 - lr: 8.9443e-05
# Epoch 46/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1466 - root_mean_squared_error: 0.2075 - val_loss: 0.0779 - val_root_mean_squared_error: 0.1387 - lr: 8.9443e-05
# Epoch 47/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.1484 - root_mean_squared_error: 0.2126 - val_loss: 0.0867 - val_root_mean_squared_error: 0.1474 - lr: 8.9443e-05
# Epoch 48/250
# 30/31 [============================>.] - ETA: 0s - loss: 0.1493 - root_mean_squared_error: 0.2113
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.000000094756084e-05.
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1519 - root_mean_squared_error: 0.2148 - val_loss: 0.0853 - val_root_mean_squared_error: 0.1425 - lr: 8.9443e-05
# Epoch 49/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1480 - root_mean_squared_error: 0.2093 - val_loss: 0.0761 - val_root_mean_squared_error: 0.1412 - lr: 4.0000e-05
# Epoch 50/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1446 - root_mean_squared_error: 0.2095 - val_loss: 0.0735 - val_root_mean_squared_error: 0.1363 - lr: 4.0000e-05
# Epoch 51/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1499 - root_mean_squared_error: 0.2100 - val_loss: 0.0766 - val_root_mean_squared_error: 0.1360 - lr: 4.0000e-05
# Epoch 52/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.1633 - root_mean_squared_error: 0.2393 - val_loss: 0.0701 - val_root_mean_squared_error: 0.1290 - lr: 4.0000e-05
# Epoch 53/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1479 - root_mean_squared_error: 0.2121 - val_loss: 0.0697 - val_root_mean_squared_error: 0.1293 - lr: 4.0000e-05
# Epoch 54/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1604 - root_mean_squared_error: 0.2244 - val_loss: 0.0732 - val_root_mean_squared_error: 0.1357 - lr: 4.0000e-05
# Epoch 55/250
# 31/31 [==============================] - 1s 35ms/step - loss: 0.1406 - root_mean_squared_error: 0.2006 - val_loss: 0.0727 - val_root_mean_squared_error: 0.1340 - lr: 4.0000e-05
# Epoch 56/250
# 31/31 [==============================] - 1s 37ms/step - loss: 0.1526 - root_mean_squared_error: 0.2218 - val_loss: 0.0694 - val_root_mean_squared_error: 0.1339 - lr: 4.0000e-05
# Epoch 57/250
# 31/31 [==============================] - 1s 34ms/step - loss: 0.1453 - root_mean_squared_error: 0.2067 - val_loss: 0.0727 - val_root_mean_squared_error: 0.1333 - lr: 4.0000e-05
# Epoch 58/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1414 - root_mean_squared_error: 0.2106 - val_loss: 0.0739 - val_root_mean_squared_error: 0.1359 - lr: 4.0000e-05
# Epoch 59/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1553 - root_mean_squared_error: 0.2189 - val_loss: 0.0699 - val_root_mean_squared_error: 0.1329 - lr: 4.0000e-05
# Epoch 60/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1501 - root_mean_squared_error: 0.2245 - val_loss: 0.0709 - val_root_mean_squared_error: 0.1296 - lr: 4.0000e-05
# Epoch 61/250
# 31/31 [==============================] - ETA: 0s - loss: 0.1535 - root_mean_squared_error: 0.2214
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.788854499504927e-05.
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1535 - root_mean_squared_error: 0.2214 - val_loss: 0.0735 - val_root_mean_squared_error: 0.1360 - lr: 4.0000e-05
# Epoch 62/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1474 - root_mean_squared_error: 0.2104 - val_loss: 0.0701 - val_root_mean_squared_error: 0.1331 - lr: 1.7889e-05
# Epoch 63/250
# 31/31 [==============================] - 1s 28ms/step - loss: 0.1366 - root_mean_squared_error: 0.2008 - val_loss: 0.0677 - val_root_mean_squared_error: 0.1294 - lr: 1.7889e-05
# Epoch 64/250
# 31/31 [==============================] - 1s 35ms/step - loss: 0.1624 - root_mean_squared_error: 0.2296 - val_loss: 0.0669 - val_root_mean_squared_error: 0.1293 - lr: 1.7889e-05
# Epoch 65/250
# 31/31 [==============================] - 1s 32ms/step - loss: 0.1332 - root_mean_squared_error: 0.1911 - val_loss: 0.0688 - val_root_mean_squared_error: 0.1307 - lr: 1.7889e-05
# Epoch 66/250
# 31/31 [==============================] - 1s 28ms/step - loss: 0.1422 - root_mean_squared_error: 0.2063 - val_loss: 0.0687 - val_root_mean_squared_error: 0.1308 - lr: 1.7889e-05
# Epoch 67/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1384 - root_mean_squared_error: 0.2038 - val_loss: 0.0669 - val_root_mean_squared_error: 0.1297 - lr: 1.7889e-05
# Epoch 68/250
# 31/31 [==============================] - 1s 34ms/step - loss: 0.1327 - root_mean_squared_error: 0.1926 - val_loss: 0.0667 - val_root_mean_squared_error: 0.1300 - lr: 1.7889e-05
# Epoch 69/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1397 - root_mean_squared_error: 0.1986 - val_loss: 0.0673 - val_root_mean_squared_error: 0.1300 - lr: 1.7889e-05
# Epoch 70/250
# 31/31 [==============================] - 1s 28ms/step - loss: 0.1451 - root_mean_squared_error: 0.2109 - val_loss: 0.0694 - val_root_mean_squared_error: 0.1320 - lr: 1.7889e-05
# Epoch 71/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1375 - root_mean_squared_error: 0.2012 - val_loss: 0.0669 - val_root_mean_squared_error: 0.1288 - lr: 1.7889e-05
# Epoch 72/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1507 - root_mean_squared_error: 0.2201 - val_loss: 0.0690 - val_root_mean_squared_error: 0.1299 - lr: 1.7889e-05
# Epoch 73/250
# 28/31 [==========================>...] - ETA: 0s - loss: 0.1324 - root_mean_squared_error: 0.1926
# Epoch 73: ReduceLROnPlateau reducing learning rate to 8.0000008402936e-06.
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1310 - root_mean_squared_error: 0.1919 - val_loss: 0.0677 - val_root_mean_squared_error: 0.1292 - lr: 1.7889e-05
# Epoch 74/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1595 - root_mean_squared_error: 0.2333 - val_loss: 0.0685 - val_root_mean_squared_error: 0.1286 - lr: 8.0000e-06
# Epoch 75/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1413 - root_mean_squared_error: 0.2018 - val_loss: 0.0664 - val_root_mean_squared_error: 0.1278 - lr: 8.0000e-06
# Epoch 76/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1452 - root_mean_squared_error: 0.2090 - val_loss: 0.0662 - val_root_mean_squared_error: 0.1286 - lr: 8.0000e-06
# Epoch 77/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1412 - root_mean_squared_error: 0.2098 - val_loss: 0.0665 - val_root_mean_squared_error: 0.1274 - lr: 8.0000e-06
# Epoch 78/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1439 - root_mean_squared_error: 0.2099 - val_loss: 0.0650 - val_root_mean_squared_error: 0.1271 - lr: 8.0000e-06
# Epoch 79/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1345 - root_mean_squared_error: 0.1963 - val_loss: 0.0654 - val_root_mean_squared_error: 0.1261 - lr: 8.0000e-06
# Epoch 80/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1476 - root_mean_squared_error: 0.2093 - val_loss: 0.0677 - val_root_mean_squared_error: 0.1275 - lr: 8.0000e-06
# Epoch 81/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1465 - root_mean_squared_error: 0.2140 - val_loss: 0.0659 - val_root_mean_squared_error: 0.1271 - lr: 8.0000e-06
# Epoch 82/250
# 31/31 [==============================] - 1s 29ms/step - loss: 0.1400 - root_mean_squared_error: 0.2074 - val_loss: 0.0669 - val_root_mean_squared_error: 0.1269 - lr: 8.0000e-06
# Epoch 83/250
# 29/31 [===========================>..] - ETA: 0s - loss: 0.1334 - root_mean_squared_error: 0.1888
# Epoch 83: ReduceLROnPlateau reducing learning rate to 3.5777091617052127e-06.
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1335 - root_mean_squared_error: 0.1906 - val_loss: 0.0671 - val_root_mean_squared_error: 0.1279 - lr: 8.0000e-06
# Epoch 84/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1535 - root_mean_squared_error: 0.2145 - val_loss: 0.0674 - val_root_mean_squared_error: 0.1276 - lr: 3.5777e-06
# Epoch 85/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1432 - root_mean_squared_error: 0.2060 - val_loss: 0.0668 - val_root_mean_squared_error: 0.1280 - lr: 3.5777e-06
# Epoch 86/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1502 - root_mean_squared_error: 0.2153 - val_loss: 0.0663 - val_root_mean_squared_error: 0.1280 - lr: 3.5777e-06
# Epoch 87/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1369 - root_mean_squared_error: 0.2031 - val_loss: 0.0664 - val_root_mean_squared_error: 0.1274 - lr: 3.5777e-06
# Epoch 88/250
# 29/31 [===========================>..] - ETA: 0s - loss: 0.1361 - root_mean_squared_error: 0.2013
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.6000001477218003e-06.
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1349 - root_mean_squared_error: 0.2001 - val_loss: 0.0661 - val_root_mean_squared_error: 0.1270 - lr: 3.5777e-06
# Epoch 89/250
# 31/31 [==============================] - 1s 32ms/step - loss: 0.1364 - root_mean_squared_error: 0.1983 - val_loss: 0.0663 - val_root_mean_squared_error: 0.1269 - lr: 1.6000e-06
# Epoch 90/250
# 31/31 [==============================] - 1s 30ms/step - loss: 0.1354 - root_mean_squared_error: 0.1981 - val_loss: 0.0659 - val_root_mean_squared_error: 0.1266 - lr: 1.6000e-06
# Epoch 91/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1342 - root_mean_squared_error: 0.1980 - val_loss: 0.0652 - val_root_mean_squared_error: 0.1262 - lr: 1.6000e-06
# Epoch 92/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1437 - root_mean_squared_error: 0.2043 - val_loss: 0.0654 - val_root_mean_squared_error: 0.1262 - lr: 1.6000e-06
# Epoch 93/250
# 30/31 [============================>.] - ETA: 0s - loss: 0.1464 - root_mean_squared_error: 0.2101
# Epoch 93: ReduceLROnPlateau reducing learning rate to 7.155418120041227e-07.
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1456 - root_mean_squared_error: 0.2098 - val_loss: 0.0655 - val_root_mean_squared_error: 0.1265 - lr: 1.6000e-06
# Epoch 94/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.1516 - root_mean_squared_error: 0.2242 - val_loss: 0.0651 - val_root_mean_squared_error: 0.1267 - lr: 7.1554e-07
# Epoch 95/250
# 31/31 [==============================] - 1s 36ms/step - loss: 0.1338 - root_mean_squared_error: 0.1967 - val_loss: 0.0651 - val_root_mean_squared_error: 0.1267 - lr: 7.1554e-07
# Epoch 96/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.1411 - root_mean_squared_error: 0.2063 - val_loss: 0.0655 - val_root_mean_squared_error: 0.1270 - lr: 7.1554e-07
# Epoch 97/250
# 31/31 [==============================] - 1s 32ms/step - loss: 0.1391 - root_mean_squared_error: 0.2051 - val_loss: 0.0651 - val_root_mean_squared_error: 0.1267 - lr: 7.1554e-07
# Epoch 98/250
# 29/31 [===========================>..] - ETA: 0s - loss: 0.1440 - root_mean_squared_error: 0.2078
# Epoch 98: ReduceLROnPlateau reducing learning rate to 3.2000003462859e-07.
# 31/31 [==============================] - 1s 32ms/step - loss: 0.1425 - root_mean_squared_error: 0.2056 - val_loss: 0.0653 - val_root_mean_squared_error: 0.1270 - lr: 7.1554e-07
# Minimum validation loss: 0.06500665843486786

# %%
from datetime import datetime

curr_time = str(datetime.now())
curr_time = curr_time[:10] + '_H' + curr_time[11:13]+'m'+curr_time[14:16]+'s'+curr_time[17:19]

model.save("modele_loss_"+str(round(history_df['val_loss'].min(),2))+"_"+curr_time)
# Out:
# INFO:tensorflow:Assets written to: modele_loss_0.06_2023-01-10_H14m26s34/assets

# %% [markdown]
# # Prediction

# %%
deep_pred = model.predict(X_test)
# Out:
# 124/124 [==============================] - 1s 3ms/step

# %%
df1 = pd.DataFrame(deep_pred, index=X_test.index, columns=['prediction_x', 'prediction_y'])
df2 = y_test
result = pd.concat([df1, df2, X_test], axis=1)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

true = result[["loc_initiator_y", "loc_initiator_x"]]
pred = result[["prediction_y", "prediction_x"]]

print("mean_absolute_error", mean_absolute_error(true, pred))
print("root_mean_squared_error", mean_squared_error(true, pred, squared=False))
# Out:
# mean_absolute_error 0.06500668235311594
# root_mean_squared_error 0.12276646972661454
