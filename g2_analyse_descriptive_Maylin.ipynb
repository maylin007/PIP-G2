# %%
import pandas as pd
df = pd.read_csv("/home/maylin/Downloads/Dataset_complete.csv")
df
# Out:
#       initiator  target protocol  nlos_indicator             t1  \
# 0           183     100      TWR        2.783982   946218857614
# 1           183     100      TWR        2.920485  1009474709646
# 2           183     100      TWR        2.536090  1072923068046
# 3           183     100      TWR        2.857669    36731534990
# 4           183     100      TWR        2.263103    99923195534
# ...         ...     ...      ...             ...            ...
# 3941        183     184      TWR        3.075243   301428484750
# 3942        183     184      TWR        3.085177   375355600014
# 3943        183     184      TWR        2.674524   449294310542
# 3944        183     184      TWR        2.727551   523279420046
# 3945        183     184      TWR        2.676824   597204949646
#
#                  t2             t3             t4      skew   tof  ...  \
# 0      946490292658   946594234510   946322802711 -2.368804  1622  ...
# ...

# %%
test = df.iloc[: , 15:]
test
# Out:
#       loc_initiator_x  loc_initiator_y  loc_initiator_z  loc_target_x  \
# 0               2.120            2.793             2.65        -3.962
# 1               2.120            2.793             2.65        -3.962
# 2               2.120            2.793             2.65        -3.962
# 3               2.120            2.793             2.65        -3.962
# 4               2.120            2.793             2.65        -3.962
# ...               ...              ...              ...           ...
# 3941           -1.276            8.914             2.65         2.120
# 3942           -1.276            8.914             2.65         2.120
# 3943           -1.276            8.914             2.65         2.120
# 3944           -1.276            8.914             2.65         2.120
# 3945           -1.276            8.914             2.65         2.120
#
#       loc_target_y  loc_target_z  distance  course_dist  \
# 0            7.931          2.65     7.962     0.000000
# ...

# %%
test.describe().round(2)
# Out:
#        loc_initiator_x  loc_initiator_y  loc_initiator_z  loc_target_x  \
# count          3946.00          3946.00          3946.00       3946.00
# mean              0.37             5.96             2.65          1.45
# std               0.98             1.77             0.00          5.09
# min              -1.28             2.79             2.65         -3.96
# 25%              -0.50             4.45             2.65         -3.13
# 50%               0.32             6.03             2.65         -1.19
# 75%               1.20             7.51             2.65          6.17
# max               2.12             8.91             2.65         11.44
#
#        loc_target_y  loc_target_z  distance  course_dist  \
# count       3946.00       3946.00   3946.00      3946.00
# mean           5.88          2.65      5.31         3.62
# std            2.25          0.00      2.94         2.03
# min            2.79          2.65      0.00         0.00
# ...

# %%
import matplotlib.pyplot as plt

# %%
test.iloc[: , :3].boxplot()
plt.figure()
test.iloc[: , 3:6].boxplot()
plt.figure()
test.iloc[: , 6:8].boxplot()
plt.figure()
test.iloc[: , 8:10].boxplot()
plt.figure()
test.iloc[: , 10:11].boxplot()
plt.figure()
test.iloc[: , 11:12].boxplot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# Les variables loc_initiator_z et loc_target_z sont inutiles car toutes égales.
# <br>Les variables distances et temperature_initiator possèdent beaucoup de valeures aberrantes.

# %%
test.iloc[: , :3].plot.hist()
plt.figure()
test.iloc[: , 3:6].plot.hist()
plt.figure()
test.iloc[: , 6:8].plot.hist()
plt.figure()
test.iloc[: , 8:10].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# Les histogrammes sont bien reparti, excepté pour la variable z.
